# %% [markdown]
# # Description
#
# We will test the custom_transformer here.

# %%
# Auto-reload all the modules. Great way to make writing and testing your modules much easier.
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import and Init

# %%
import h2o
from h2o.automl import H2OAutoML

import os
import pickle
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from feature_engine.wrappers import SklearnTransformerWrapper

# %%
from h2o_remake import H2O_Remake as hr

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# Warning: Your H2O cluster version is too old (1 year, 3 months and 30 days)! Please download and install the latest version from http://h2o.ai/download/
# --------------------------  ------------------------------------------------------------------
# H2O cluster uptime:         3 days 1 hour 51 mins
# H2O cluster timezone:       Etc/UTC
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.28.0.1
# H2O cluster version age:    1 year, 3 months and 30 days !!!
# H2O cluster name:           H2O_from_python_unknownUser_i1hfgl
# H2O cluster total nodes:    1
# H2O cluster free memory:    5.859 Gb
# H2O cluster total cores:    8
# H2O cluster allowed cores:  8
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:       {'http': None, 'https': None}
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python version:             3.8.6 final
# --------------------------  ------------------------------------------------------------------

# %% [markdown]
# # Load Data

# %%
# Load the data
data_df = pd.read_csv('./data/winequality-red.csv', sep=";")

# %%
# Split the data into training and test sets. (0.75, 0.25) split.
train, test = train_test_split(data_df)

# %%
train_x = train.drop(["quality"], axis=1)
test_x = test.drop(["quality"], axis=1)
train_y = train[["quality"]]
test_y = test[["quality"]]

# %%
train_x.sample(3)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 597            11.9              0.58         0.58             1.9      0.071
# 859             6.8              0.56         0.22             1.8      0.074
# 1524            6.0              0.42         0.19             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 597                   5.0                  18.0  0.99800  3.09       0.63
# 859                  15.0                  24.0  0.99438  3.40       0.82
# 1524                 22.0                  47.0  0.99522  3.39       0.78
#
#       alcohol
# 597      10.0
# 859      11.2
# 1524     10.0

# %%
train_y.sample(3)
# Out:
#       quality
# 1344        5
# 1026        6
# 142         6

# %% [markdown]
# # Apply Feature Engine

# %%
train_x.sample(3)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 84              6.3              0.30         0.48             1.8      0.069
# 1137           10.4              0.52         0.45             2.0      0.080
# 789             8.6              0.63         0.17             2.9      0.099
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 84                   18.0                  61.0  0.99590  3.44       0.78
# 1137                  6.0                  13.0  0.99774  3.22       0.76
# 789                  21.0                 119.0  0.99800  3.09       0.52
#
#       alcohol
# 84       10.3
# 1137     11.4
# 789       9.3

# %%
train_x.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
# set up the wrapper
cols = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']
scaler = SklearnTransformerWrapper(transformer = StandardScaler(),
                                    variables = cols)

#
scaled_train_x  = scaler.fit_transform(train_x)

# %%
scaled_train_x.sample(3)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1348      -0.662310          0.706868    -1.266041       -0.523692  -0.204618
# 729       -1.121931          1.873392    -1.266041        0.472985  -0.357326
# 1593      -0.892121          0.512448    -1.008091       -0.452500  -0.422773
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 1348            -0.836654             -1.030379 -0.485026  0.212468
# 729              1.050115              0.336635 -0.955017  1.950275
# 1593             1.144453             -0.257719 -0.139286  0.727374
#
#       sulphates   alcohol
# 1348  -1.527557 -0.862706
# 729   -0.956111  2.169383
# 1593   0.929660 -0.862706

# %% [markdown]
# # Train with H2O

# %% [markdown]
# ## Select x, y Cols

# %%
list(scaled_train_x.columns )
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol']

# %%
x_cols = \
['fixed acidity',
 'volatile acidity',
 'citric acid',
 'residual sugar',
 'chlorides',
 'free sulfur dioxide',
 'total sulfur dioxide',
 'density',
 'pH',
 'sulphates',
 'alcohol',
]

y_col = 'quality'

# %% [markdown]
# ## Define Column Types

# %%
temp_hdf = h2o.H2OFrame( scaled_train_x.sample(5))
temp_hdf.types
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# 1195     10.7      5.0  0.003180  0.018558  0.568420  0.391807  0.012932
# 1196     10.0      5.0  0.007822  0.051106  0.456651  0.409680  0.054229
# 1197      9.7      5.0  0.003033  0.020384  0.582462  0.378716  0.010498
# 1198      9.8      5.0  0.003178  0.020950  0.572855  0.385885  0.011992
#
#            8.0
# 0     0.005183
# 1     0.040102
# 2     0.005005
# 3     0.023069
# 4     0.005162
# ...        ...
# 1194  0.005138
# 1195  0.005103
# 1196  0.020511
# 1197  0.004907
# 1198  0.005140
#
# [1199 rows x 18 columns]

# %% [markdown]
# ## Make Pipeline

# %%
steps=[ ('scaler', scaler),
        ('h2o_est', h2o_estimator),
      ]
steps
# Out:
# [('scaler',
#   SklearnTransformerWrapper(transformer=StandardScaler(),
#                             variables=['fixed acidity', 'volatile acidity',
#                                        'citric acid', 'residual sugar',
#                                        'chlorides', 'free sulfur dioxide',
#                                        'total sulfur dioxide', 'density', 'pH',
#                                        'sulphates', 'alcohol'])),
#  ('h2o_est',
#   Custom_Estimator(model_id='StackedEnsemble_BestOfFamily_AutoML_20210416_032447'))]

# %%
pipeline = Pipeline(steps)

# %%
pipeline.transform(test_x)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         1.405984         -0.431881     0.281658       -0.025353   0.253507
# 1        -0.834668         -0.043040    -0.131062        0.045838  -0.139171
# 2        -0.719763          0.790191    -1.420811       -0.167736  -0.095541
# 3        -0.949574         -0.376332    -0.182652       -0.594883  -0.226433
# 4        -0.547405          0.401350    -0.079472       -0.310118  -0.095541
# ..             ...               ...          ...             ...        ...
# 395      -1.007026         -0.043040    -1.214451       -0.238927  -0.400957
# 396      -0.662310          0.706868    -1.266041       -0.523692  -0.204618
# 397       0.601647         -1.598405     0.281658       -0.167736  -0.575481
# 398      -0.317595         -0.542979     2.190486       -0.452500   8.216158
# 399      -0.432500         -0.209686     0.281658       -0.452500  -0.291880
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0               0.389746             -0.257719  0.762881 -0.431164   0.301070
# 1              -0.553638             -0.287436  0.044389  0.984827  -0.898967
# 2               0.201069             -0.584613  0.492771  0.856100  -0.670388
# 3               0.201069             -0.376589 -1.063061  0.534284  -0.327521
# 4               0.106731              1.317319 -0.328362 -0.109348  -0.556099
# ..                   ...                   ...       ...       ...        ...
# 395            -0.742315             -0.941226 -0.630885  0.598647  -0.156087
# 396            -0.836654             -1.030379 -0.485026  0.212468  -1.527557
# 397             3.408576              0.782401  0.590011  1.049190   1.386817
# 398             0.578423              0.604095  0.341510 -1.139159   3.558311
# 399             1.050115              1.139013  0.157835  0.663011  -0.441810
#
#       alcohol  predict       3.0       4.0       5.0       6.0       7.0  \
# 0    0.369080      5.0  0.008023  0.030268  0.501339  0.331988  0.108980
# 1    0.558586      5.0  0.007865  0.047239  0.447627  0.437824  0.046210
# 2   -0.957459      5.0  0.003207  0.039739  0.826101  0.117432  0.008798
# 3    0.179575      6.0  0.005579  0.016618  0.097656  0.812977  0.056234
# 4   -0.578448      5.0  0.002647  0.024864  0.729921  0.230246  0.007788
# ..        ...      ...       ...       ...       ...       ...       ...
# 395 -0.957459      6.0  0.007469  0.036324  0.279815  0.615592  0.049016
# 396 -0.862706      5.0  0.003405  0.042885  0.848187  0.094316  0.006986
# 397 -0.199437      7.0  0.007718  0.024551  0.093077  0.219945  0.620760
# 398 -0.957459      5.0  0.003490  0.035341  0.753957  0.189167  0.012327
# 399 -1.336470      5.0  0.002296  0.025775  0.806475  0.154829  0.006657
#
#           8.0
# 0    0.019402
# 1    0.013235
# 2    0.004724
# 3    0.010936
# 4    0.004534
# ..        ...
# 395  0.011785
# 396  0.004220
# 397  0.033950
# 398  0.005719
# 399  0.003967
#
# [400 rows x 18 columns]

# %%
pipeline.predict(test_x)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         1.405984         -0.431881     0.281658       -0.025353   0.253507
# 1        -0.834668         -0.043040    -0.131062        0.045838  -0.139171
# 2        -0.719763          0.790191    -1.420811       -0.167736  -0.095541
# 3        -0.949574         -0.376332    -0.182652       -0.594883  -0.226433
# 4        -0.547405          0.401350    -0.079472       -0.310118  -0.095541
# ..             ...               ...          ...             ...        ...
# 395      -1.007026         -0.043040    -1.214451       -0.238927  -0.400957
# 396      -0.662310          0.706868    -1.266041       -0.523692  -0.204618
# 397       0.601647         -1.598405     0.281658       -0.167736  -0.575481
# 398      -0.317595         -0.542979     2.190486       -0.452500   8.216158
# 399      -0.432500         -0.209686     0.281658       -0.452500  -0.291880
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0               0.389746             -0.257719  0.762881 -0.431164   0.301070
# 1              -0.553638             -0.287436  0.044389  0.984827  -0.898967
# 2               0.201069             -0.584613  0.492771  0.856100  -0.670388
# 3               0.201069             -0.376589 -1.063061  0.534284  -0.327521
# 4               0.106731              1.317319 -0.328362 -0.109348  -0.556099
# ..                   ...                   ...       ...       ...        ...
# 395            -0.742315             -0.941226 -0.630885  0.598647  -0.156087
# 396            -0.836654             -1.030379 -0.485026  0.212468  -1.527557
# 397             3.408576              0.782401  0.590011  1.049190   1.386817
# 398             0.578423              0.604095  0.341510 -1.139159   3.558311
# 399             1.050115              1.139013  0.157835  0.663011  -0.441810
#
#       alcohol  predict       3.0       4.0       5.0       6.0       7.0  \
# 0    0.369080      5.0  0.008023  0.030268  0.501339  0.331988  0.108980
# 1    0.558586      5.0  0.007865  0.047239  0.447627  0.437824  0.046210
# 2   -0.957459      5.0  0.003207  0.039739  0.826101  0.117432  0.008798
# 3    0.179575      6.0  0.005579  0.016618  0.097656  0.812977  0.056234
# 4   -0.578448      5.0  0.002647  0.024864  0.729921  0.230246  0.007788
# ..        ...      ...       ...       ...       ...       ...       ...
# 395 -0.957459      6.0  0.007469  0.036324  0.279815  0.615592  0.049016
# 396 -0.862706      5.0  0.003405  0.042885  0.848187  0.094316  0.006986
# 397 -0.199437      7.0  0.007718  0.024551  0.093077  0.219945  0.620760
# 398 -0.957459      5.0  0.003490  0.035341  0.753957  0.189167  0.012327
# 399 -1.336470      5.0  0.002296  0.025775  0.806475  0.154829  0.006657
#
#           8.0
# 0    0.019402
# 1    0.013235
# 2    0.004724
# 3    0.010936
# 4    0.004534
# ..        ...
# 395  0.011785
# 396  0.004220
# 397  0.033950
# 398  0.005719
# 399  0.003967
#
# [400 rows x 18 columns]

# %%
pipeline.fit(train_x)
# Out:
# Pipeline(steps=[('scaler',
#                  SklearnTransformerWrapper(transformer=StandardScaler(),
#                                            variables=['fixed acidity',
#                                                       'volatile acidity',
#                                                       'citric acid',
#                                                       'residual sugar',
#                                                       'chlorides',
#                                                       'free sulfur dioxide',
#                                                       'total sulfur dioxide',
#                                                       'density', 'pH',
#                                                       'sulphates',
#                                                       'alcohol'])),
#                 ('h2o_est',
#                  Custom_Estimator(model_id='StackedEnsemble_BestOfFamily_AutoML_20210416_032447'))])

# %% [markdown]
# # Save the Pipeline as Pickle

# %%
with open('test_custom_estimator.pickle', 'wb') as f:
    pickle.dump(pipeline, f)

# %%
h2o.remove(aml.leader.model_id)

# %%
del scaler

# %% [markdown]
# # Restore Pipeline and Predict

# %%
with open('test_custom_estimator.pickle', 'rb') as f:
    pipeline2 = pickle.load(f)

# %%
pipeline2.predict(test_x)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# stackedensemble prediction progress: |████████████████████████████████████| 100%
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         1.405984         -0.431881     0.281658       -0.025353   0.253507
# 1        -0.834668         -0.043040    -0.131062        0.045838  -0.139171
# 2        -0.719763          0.790191    -1.420811       -0.167736  -0.095541
# 3        -0.949574         -0.376332    -0.182652       -0.594883  -0.226433
# 4        -0.547405          0.401350    -0.079472       -0.310118  -0.095541
# ..             ...               ...          ...             ...        ...
# 395      -1.007026         -0.043040    -1.214451       -0.238927  -0.400957
# 396      -0.662310          0.706868    -1.266041       -0.523692  -0.204618
# 397       0.601647         -1.598405     0.281658       -0.167736  -0.575481
# 398      -0.317595         -0.542979     2.190486       -0.452500   8.216158
# 399      -0.432500         -0.209686     0.281658       -0.452500  -0.291880
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0               0.389746             -0.257719  0.762881 -0.431164   0.301070
# 1              -0.553638             -0.287436  0.044389  0.984827  -0.898967
# 2               0.201069             -0.584613  0.492771  0.856100  -0.670388
# 3               0.201069             -0.376589 -1.063061  0.534284  -0.327521
# 4               0.106731              1.317319 -0.328362 -0.109348  -0.556099
# ..                   ...                   ...       ...       ...        ...
# 395            -0.742315             -0.941226 -0.630885  0.598647  -0.156087
# 396            -0.836654             -1.030379 -0.485026  0.212468  -1.527557
# 397             3.408576              0.782401  0.590011  1.049190   1.386817
# 398             0.578423              0.604095  0.341510 -1.139159   3.558311
# 399             1.050115              1.139013  0.157835  0.663011  -0.441810
#
#       alcohol  predict       3.0       4.0       5.0       6.0       7.0  \
# 0    0.369080      5.0  0.008023  0.030268  0.501339  0.331988  0.108980
# 1    0.558586      5.0  0.007865  0.047239  0.447627  0.437824  0.046210
# 2   -0.957459      5.0  0.003207  0.039739  0.826101  0.117432  0.008798
# 3    0.179575      6.0  0.005579  0.016618  0.097656  0.812977  0.056234
# 4   -0.578448      5.0  0.002647  0.024864  0.729921  0.230246  0.007788
# ..        ...      ...       ...       ...       ...       ...       ...
# 395 -0.957459      6.0  0.007469  0.036324  0.279815  0.615592  0.049016
# 396 -0.862706      5.0  0.003405  0.042885  0.848187  0.094316  0.006986
# 397 -0.199437      7.0  0.007718  0.024551  0.093077  0.219945  0.620760
# 398 -0.957459      5.0  0.003490  0.035341  0.753957  0.189167  0.012327
# 399 -1.336470      5.0  0.002296  0.025775  0.806475  0.154829  0.006657
#
#           8.0
# 0    0.019402
# 1    0.013235
# 2    0.004724
# 3    0.010936
# 4    0.004534
# ..        ...
# 395  0.011785
# 396  0.004220
# 397  0.033950
# 398  0.005719
# 399  0.003967
#
# [400 rows x 18 columns]

# %% [markdown]
# # Completion

# %%
import datetime
print( datetime.datetime.now() )
# Out:
# 2021-04-16 03:25:32.467212
